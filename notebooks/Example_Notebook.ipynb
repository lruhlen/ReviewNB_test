# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
plt.style.use('ggplot')

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x**2) * np.exp(-1.0 * x)

# %%
plt.plot(x,y)
